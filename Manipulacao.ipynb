# %% [markdown]
# # Conectando no excel e analisando dados...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = 'C:/Users/Luiz Augusto/git/PortifolioLR/serie_2001_2019_TCU.xls'
x =pd.read_excel(data)
x.head()
# Out:
#   Brasil, Grandes Regiões e Unidades da Federação       2001       2002  \
# 0                                          Brasil  172385826  174632960
# 1                                    Região Norte   13245084   13504599
# 2                                        Rondônia    1407886    1431777
# 3                                            Acre     574355     586942
# 4                                        Amazonas    2900240    2961801
#
#         2003       2004       2005       2006       2007       2008  \
# 0  176871437  181581024  184184264  186770562  183989711  189612814
# 1   13784881   14373260   14698878   15022060   14623317   15142684
# 2    1455907    1562085    1534594    1562417    1453756    1493566
# 3     600595     630328     669736     686652     655385     680073
# 4    3031068    3138726    3232330    3311026    3221940    3341096
#
#         2009       2010       2011       2012       2013       2014  \
# ...

# %%
z = x[['Brasil, Grandes Regiões e Unidades da Federação',2019]]
l = x['Brasil, Grandes Regiões e Unidades da Federação']

# %%
plt.plot(x['Brasil, Grandes Regiões e Unidades da Federação'],x[2019])
plt.xticks(l,[str(i) for i in l],rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x21397135248>,
# ...
#  <a list of 33 Text xticklabel objects>)
